# %% [markdown]
# # AI Travel Premium — Telegram MVP
# Этот ноутбук запускает проект полностью из GitHub. Добавьте в Colab Secrets: `TG_TOKEN2` и `GIGACHAT_CREDENTIALS`, затем выполните **Runtime → Run all**.

# %%
# !rm -rf /content/Vibe-coding
# !git clone https://github.com/VictorKVS/Vibe-coding.git /content/Vibe-coding
# %cd /content/Vibe-coding/DZ_4_Menus_buttons_dialog_scripts
# !pip -q install -r requirements.txt

# %%
import os
from google.colab import userdata

os.environ['TG_TOKEN2'] = userdata.get('TG_TOKEN2')
os.environ['GIGACHAT_CREDENTIALS'] = userdata.get('GIGACHAT_CREDENTIALS')
print('Secrets loaded:', bool(os.environ.get('TG_TOKEN2')), bool(os.environ.get('GIGACHAT_CREDENTIALS')))

# %%
from src.catalog import build_sqlite
build_sqlite('data/tours.csv', 'data/ai_travel.db')
print('SQLite catalog prepared')

# %%
# !python -m src.main
